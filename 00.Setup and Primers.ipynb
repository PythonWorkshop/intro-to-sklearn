# %% [markdown]
# ## Tutorial Setup

# %% [markdown]
# ### Check your install

# %%
import numpy

# %%
import scipy

# %%
import matplotlib

# %%
import sklearn

# %%
import pandas

# %% [markdown]
# Finding the location of an installed package and its version:

# %%
numpy.__path__

# %%
numpy.__version__

# %% [markdown]
# ## A NumPy primer

# %% [markdown]
# ### NumPy array dtypes and shapes

# %%
import numpy as np

# %%
a = np.array([1, 2, 3])

# %%
a

# %%
b = np.array([[0, 2, 4], [1, 3, 5]])

# %%
b

# %%
b.shape

# %%
b.dtype

# %%
a.shape

# %%
a.dtype

# %%
np.zeros(5)

# %%
np.ones(shape=(3, 4), dtype=np.int32)

# %% [markdown]
# ### Common array operations

# %%
c = b * 0.5

# %%
c

# %%
c.shape

# %%
c.dtype

# %%
a

# %%
d = a + c

# %%
d

# %%
d[0]

# %%
d[0, 0]

# %%
d[:, 0]

# %%
d.sum()

# %%
d.mean()

# %%
d.sum(axis=0)

# %%
d.mean(axis=1)

# %% [markdown]
# ### Reshaping and inplace update

# %%
e = np.arange(12)

# %%
e

# %%
f = e.reshape(3, 4)

# %%
f

# %%
e

# %%
e[5:] = 0

# %%
e

# %%
f

# %% [markdown]
# ### Combining arrays

# %%
a

# %%
b

# %%
d

# %%
np.concatenate([a, a, a])

# %%
np.vstack([a, b, d])

# %%
np.hstack([b, d])

# %% [markdown]
# ## A Matplotlib primer

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2, 10)

# %%
x
# Out:
# array([ 0.        ,  0.22222222,  0.44444444,  0.66666667,  0.88888889,
#         1.11111111,  1.33333333,  1.55555556,  1.77777778,  2.        ])

# %%
plt.plot(x, 'o-');

# %%
plt.plot(x, x, 'o-', label='linear')
plt.plot(x, x ** 2, 'x-', label='quadratic')

plt.legend(loc='best')
plt.title('Linear vs Quadratic progression')
plt.xlabel('Input')
plt.ylabel('Output');

# %%
samples = np.random.normal(loc=1.0, scale=0.5, size=1000)

# %%
samples.shape
# Out:
# (1000,)

# %%
samples.dtype
# Out:
# dtype('float64')

# %%
samples[:30]
# Out:
# array([-0.08488496,  0.71785004,  1.10696799,  1.16224357,  1.58758899,
#         1.13700952,  0.83749942,  1.13569133,  0.65508571,  0.43025854,
#         0.76300165,  0.59725104,  1.80789741,  1.01242668,  0.08388674,
#         1.15231727,  1.28628661,  1.34092282,  1.15296271,  2.0480946 ,
#         1.14825911,  1.0986468 ,  0.5263969 ,  0.50966506,  1.00203301,
#         1.65215524,  0.56314775,  1.46713249,  1.64521118,  0.88886672])

# %%
plt.hist(samples, bins=50);

# %%
samples_1 = np.random.normal(loc=1, scale=.5, size=10000)
samples_2 = np.random.standard_t(df=10, size=10000)

# %%
bins = np.linspace(-3, 3, 50)
_ = plt.hist(samples_1, bins=bins, alpha=0.5, label='samples 1')
_ = plt.hist(samples_2, bins=bins, alpha=0.5, label='samples 2')
plt.legend(loc='upper left');

# %%
plt.scatter(samples_1, samples_2, alpha=0.1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
samples_3 = np.random.normal(loc=2, scale=.5, size=10000)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(samples_1, samples_2, alpha=0.1, c='b', marker="s", label='first')
ax1.scatter(samples_3, samples_2, alpha=0.1, c='r', marker="o", label='second')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Credits
# =======
#
# Most of this material is adapted from the Olivier Grisel's 2015 tutorial:
#
# [https://github.com/ogrisel/parallel_ml_tutorial](https://github.com/ogrisel/parallel_ml_tutorial)
#
# Original author:
#
# - Olivier Grisel [@ogrisel](https://twitter.com/ogrisel) | http://ogrisel.com
